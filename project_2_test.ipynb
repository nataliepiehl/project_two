# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine

# %%
# Create engine using the `demographics.sqlite` database file
engine = create_engine("sqlite:///Resources/archive/database.sqlite")

# %%
# Declare a Base using `automap_base()`
Base = automap_base()

# %%
# Use the Base class to reflect the database tables
Base.prepare(engine, reflect=True)

# %%
# Print all of the classes mapped to the Base
Base.classes.keys()
# Out:
# ['county_facts']

# %%
Facts = Base.classes.county_facts

# %%
# Create a session
session = Session(engine)

# %%
for row in session.query(Facts, Facts.area_name, Facts.state_abbreviation).all():
    print(row)
# Out:
# (<sqlalchemy.ext.automap.county_facts object at 0x000001A743986790>, 'United States', '')
# (<sqlalchemy.ext.automap.county_facts object at 0x000001A74394AE80>, 'Alabama', '')
# (<sqlalchemy.ext.automap.county_facts object at 0x000001A748205FD0>, 'Autauga County', 'AL')
# (<sqlalchemy.ext.automap.county_facts object at 0x000001A746058850>, 'Baldwin County', 'AL')
# (<sqlalchemy.ext.automap.county_facts object at 0x000001A74820E2B0>, 'Barbour County', 'AL')
# (<sqlalchemy.ext.automap.county_facts object at 0x000001A748227760>, 'Bibb County', 'AL')
# (<sqlalchemy.ext.automap.county_facts object at 0x000001A748227700>, 'Blount County', 'AL')
# (<sqlalchemy.ext.automap.county_facts object at 0x000001A748227820>, 'Bullock County', 'AL')
# (<sqlalchemy.ext.automap.county_facts object at 0x000001A748227880>, 'Butler County', 'AL')
# (<sqlalchemy.ext.automap.county_facts object at 0x000001A7482278E0>, 'Calhoun County', 'AL')
# ...

# %%
states = session.query(Facts).group_by(Facts.state_abbreviation).count()
print(states)
# Out:
# 52
